# %% [markdown]
# # Quickstart: Analytical Extrapolation
#
# This is a click-and-go notebook for the built-in Low and Lou analytical reference field.
#
# Workflow:
# 1. Edit the parameter cell below if you want.
# 2. Run all cells.
# 3. Open the exported `.vtk` or `.npz` result from the output directory.

# %%
# Edit only this cell for a simple run
CASE = 1
EPOCHS = 20
OUTPUT_NAME = "analytical_case1_quickstart"
EXPORT_FORMATS = ["vtk", "npz"]

# %%
from copy import deepcopy
from pathlib import Path

from nf2.core.runner import run
from nf2.export.core import export_checkpoint
from nf2.train.util import load_yaml_config

repo_root = Path.cwd().resolve()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent

config_path = repo_root / "config" / "analytical" / f"case{CASE}.yaml"
config = load_yaml_config(str(config_path))
config["base_path"] = str(repo_root / "results" / "notebooks" / OUTPUT_NAME)
config["work_directory"] = str(repo_root / "work" / "notebooks" / OUTPUT_NAME)
config["training"] = deepcopy(config.get("training", {}))
config["training"]["epochs"] = EPOCHS
config["logging"] = deepcopy(config.get("logging", {}))
config["logging"]["offline"] = True

config
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 4
#       1 from copy import deepcopy
#       2 from pathlib import Path
# ----> 4 from nf2.core.runner import run
#       5 from nf2.export.core import export_checkpoint
#       6 from nf2.train.util import load_yaml_config
#
# File ~/PycharmProjects/NF2/nf2/core/runner.py:9
#       6 from copy import deepcopy
#       8 import torch
# ----> 9 from pytorch_lightning import Trainer
#      10 from pytorch_lightning.callbacks import LambdaCallback, ModelCheckpoint
#      11 from pytorch_lightning.loggers import WandbLogger
#
# File ~/anaconda3/envs/development/lib/python3.10/site-packages/pytorch_lightning/__init__.py:25
#      22     _logger.addHandler(logging.StreamHandler())
#      23     _logger.propagate = False
# ---> 25 from lightning_fabric.utilities.seed import seed_everything  # noqa: E402
# ...

# %%
run(**config)

# %%
checkpoint_path = Path(config["base_path"]) / "extrapolation_result.nf2"
exports = {fmt: export_checkpoint(str(checkpoint_path), fmt) for fmt in EXPORT_FORMATS}
checkpoint_path, exports
